# %%
import json
import csv
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score
from sklearn.metrics import confusion_matrix, silhouette_score
from sklearn.metrics import homogeneity_score, completeness_score, v_measure_score
import argparse
import os
from collections import defaultdict

# %%
def find_the_way(path,file_format,con=""):
    files_add = []
    # r=root, d=directories, f = files
    for r, d, f in os.walk(path):
        for file in f:
            if file_format in file:
                if con in file:
                    files_add.append(os.path.join(r, file))  
            
    return files_add
path="./community_results"
files_add=find_the_way(path,'_communities.csv')
files_add
# Out:
# ['./community_results\\fast_greedy_communities.csv',
#  './community_results\\gat_gnn_communities.csv',
#  './community_results\\gcn_gnn_communities.csv',
#  './community_results\\infomap_communities.csv',
#  './community_results\\label_propagation_communities.csv',
#  './community_results\\leiden_communities.csv',
#  './community_results\\louvain_communities.csv',
#  './community_results\\Node2Vec_communities.csv']

# %%
import json
import csv
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score
from sklearn.metrics import confusion_matrix, silhouette_score
from sklearn.metrics import homogeneity_score, completeness_score, v_measure_score
import os
from collections import defaultdict





def load_ground_truth(json_file):
    """Loads ground truth labels from a JSON file."""
    with open(json_file, 'r') as f:
        gt_data = json.load(f)
    ap_to_floor = {int(k): v for k, v in gt_data.items()}
    return ap_to_floor

def load_clustering_result(csv_file):
    """Loads clustering results from a CSV file."""
    clusters = []
    with open(csv_file, 'r') as f:
        csv_reader = csv.reader(f)
        for row in csv_reader:
            cluster = [int(item.strip()) for item in row if item.strip() and item.strip().isdigit()]
            if cluster:
                clusters.append(cluster)
    ap_to_cluster = {}
    for cluster_id, aps in enumerate(clusters):
        for ap in aps:
            ap_to_cluster[ap] = cluster_id
    return ap_to_cluster, clusters

def map_clusters_to_floors(ap_to_floor, ap_to_cluster):
    """Maps clusters to floors (majority floor in the cluster becomes its label)."""
    cluster_floor_counts = defaultdict(lambda: defaultdict(int))
    common_aps = set(ap_to_floor.keys()) & set(ap_to_cluster.keys())
    for ap in common_aps:
        floor = ap_to_floor[ap]
        cluster = ap_to_cluster[ap]
        cluster_floor_counts[cluster][floor] += 1
    cluster_to_floor = {}
    for cluster, floor_counts in cluster_floor_counts.items():
        cluster_to_floor[cluster] = max(floor_counts.items(), key=lambda x: x[1])[0]
    return cluster_to_floor

def create_true_pred_arrays(ap_to_floor, ap_to_cluster, cluster_to_floor):
    """Creates arrays of true and predicted labels for evaluation."""
    common_aps = sorted(set(ap_to_floor.keys()) & set(ap_to_cluster.keys()))
    y_true = np.array([ap_to_floor[ap] for ap in common_aps])
    y_pred_raw = np.array([ap_to_cluster[ap] for ap in common_aps])
    y_pred_mapped = np.array([cluster_to_floor[ap_to_cluster[ap]] for ap in common_aps])
    return common_aps, y_true, y_pred_raw, y_pred_mapped

def evaluate_clustering(y_true, y_pred, prefix=""):
    """Evaluates clustering performance and returns metrics."""
    results = {}
    results[f"{prefix}ari"] = adjusted_rand_score(y_true, y_pred)
    results[f"{prefix}nmi"] = normalized_mutual_info_score(y_true, y_pred)
    results[f"{prefix}homogeneity"] = homogeneity_score(y_true, y_pred)
    results[f"{prefix}completeness"] = completeness_score(y_true, y_pred)
    results[f"{prefix}v_measure"] = v_measure_score(y_true, y_pred)
    if prefix == "mapped_":
        results[f"{prefix}accuracy"] = accuracy_score(y_true, y_pred)
        precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted')
        results[f"{prefix}precision"] = precision
        results[f"{prefix}recall"] = recall
        results[f"{prefix}f1"] = f1
    return results

def generate_confusion_matrix(y_true, y_pred, output_file, title):
    """Generates and saves a confusion matrix plot."""
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title(title)
    plt.savefig(output_file)
    plt.show()  # Jupyter Notebook'ta grafiği göstermek için eklendi
    plt.close()

def analyze_clusters(clusters, ap_to_floor, output_dir):
    """Analyzes each cluster and visualizes floor distribution."""
    results = []
    for cluster_id, aps in enumerate(clusters):
        floor_counts = defaultdict(int)
        valid_aps = 0
        for ap in aps:
            if ap in ap_to_floor:
                floor_counts[ap_to_floor[ap]] += 1
                valid_aps += 1
        if not valid_aps:
            continue
        percentages = {floor: (count / valid_aps) * 100 for floor, count in floor_counts.items()}
        dominant_floor = max(percentages.items(), key=lambda x: x[1]) if percentages else (None, 0)
        results.append({
            'cluster_id': cluster_id,
            'total_aps': len(aps),
            'valid_aps': valid_aps,
            'floor_counts': dict(floor_counts),
            'floor_percentages': percentages,
            'dominant_floor': dominant_floor[0],
            'dominant_percentage': dominant_floor[1]
        })
        if valid_aps > 0:
            plt.figure(figsize=(10, 6))
            floors = list(floor_counts.keys())
            counts = list(floor_counts.values())
            bars = plt.bar(floors, counts)
            plt.xlabel('Floor')
            plt.ylabel('Number of APs')
            plt.title(f'Cluster {cluster_id} Floor Distribution')
            for bar in bars:
                height = bar.get_height()
                plt.text(bar.get_x() + bar.get_width()/2., height + 0.1,
                         f'{int(height)}', ha='center', va='bottom')
            plt.savefig(os.path.join(output_dir, f'cluster_{cluster_id}_distribution.pdf'))
            #plt.show()  # Jupyter Notebook'ta grafiği göstermek için eklendi
            plt.close()
    with open(os.path.join(output_dir, 'cluster_analysis.json'), 'w', encoding='utf-8') as f:
        json.dump(results, f, ensure_ascii=False, indent=4)
    return results


for file in files_add:
    
    # 1. Setup file paths
    gt_file = 'community_results/GT.json'
    result_file = file
    
    # Calculate a cleaner folder name (optional improvement over [2:-3])
    # If your file string is consistently "./filename.csv", [2:-3] works, 
    # but strictly speaking, os.makedirs must run before saving.
    folder_name = file[2:-3] 
    output_dir = f'./results/{folder_name}/' 
    
    # --- FIX 1: Create the directory correctly ---
    # We use os.makedirs (not s.makedirs) and ensure it exists before writing files
    os.makedirs(output_dir, exist_ok=True)
    
    # 2. Run Main Logic
    ap_to_floor = load_ground_truth(gt_file)
    ap_to_cluster, clusters = load_clustering_result(result_file)
    cluster_to_floor = map_clusters_to_floors(ap_to_floor, ap_to_cluster)
    
    common_aps, y_true, y_pred_raw, y_pred_mapped = create_true_pred_arrays(
        ap_to_floor, ap_to_cluster, cluster_to_floor
    )
    
    # 3. Evaluate
    raw_results = evaluate_clustering(y_true, y_pred_raw, prefix="raw_")
    
    # --- FIX 2: Handle Zero Division Warning ---
    # We modify evaluate_clustering logic inline here or you can update the function above.
    # For clarity, I will calculate the mapped metrics here with the fix:
    
    mapped_results = {}
    mapped_results["mapped_ari"] = adjusted_rand_score(y_true, y_pred_mapped)
    mapped_results["mapped_nmi"] = normalized_mutual_info_score(y_true, y_pred_mapped)
    mapped_results["mapped_homogeneity"] = homogeneity_score(y_true, y_pred_mapped)
    mapped_results["mapped_completeness"] = completeness_score(y_true, y_pred_mapped)
    mapped_results["mapped_v_measure"] = v_measure_score(y_true, y_pred_mapped)
    mapped_results["mapped_accuracy"] = accuracy_score(y_true, y_pred_mapped)
    
    # The specific fix for the Warning:
    precision, recall, f1, _ = precision_recall_fscore_support(
        y_true, y_pred_mapped, 
        average='weighted', 
        zero_division=0  # <--- Added this to silence the warning
    )
    
    mapped_results["mapped_precision"] = precision
    mapped_results["mapped_recall"] = recall
    mapped_results["mapped_f1"] = f1
    
    all_results = {**raw_results, **mapped_results}
    
    # 4. Print Results
    print(f"\n=== {folder_name} CLUSTERING PERFORMANCE METRICS ===")
    print("\n--- Raw Cluster Evaluation ---")
    print(f"Adjusted Rand Index: {raw_results['raw_ari']:.4f}")
    print(f"Normalized Mutual Information: {raw_results['raw_nmi']:.4f}")
    print(f"Homogeneity: {raw_results['raw_homogeneity']:.4f}")
    print(f"Completeness: {raw_results['raw_completeness']:.4f}")
    print(f"V-measure: {raw_results['raw_v_measure']:.4f}")
    
    print("\n--- Cluster-to-Floor Mapped Evaluation ---")
    print(f"Accuracy: {mapped_results['mapped_accuracy']:.4f}")
    print(f"Precision: {mapped_results['mapped_precision']:.4f}")
    print(f"Recall: {mapped_results['mapped_recall']:.4f}")
    print(f"F1-Score: {mapped_results['mapped_f1']:.4f}")
    print(f"Adjusted Rand Index: {mapped_results['mapped_ari']:.4f}")
    print(f"Normalized Mutual Information: {mapped_results['mapped_nmi']:.4f}")
    
    # 5. Save Results (This will now work because output_dir exists)
    with open(os.path.join(output_dir, 'performance_metrics.json'), 'w', encoding='utf-8') as f:
        json.dump(all_results, f, ensure_ascii=False, indent=4)
    
    # 6. Generate Plots
    generate_confusion_matrix(
        y_true, y_pred_raw,
        os.path.join(output_dir, 'confusion_matrix_raw.pdf'),
        'Confusion Matrix for Raw Clusters'
    )
    generate_confusion_matrix(
        y_true, y_pred_mapped,
        os.path.join(output_dir, 'confusion_matrix_mapped.pdf'),
        'Confusion Matrix for Mapped Clusters'
    )
    
    # 7. Analyze Clusters
    cluster_analysis = analyze_clusters(clusters, ap_to_floor, output_dir)
    purities = [item['dominant_percentage'] for item in cluster_analysis]
    avg_purity = sum(purities) / len(purities) if purities else 0
    
    print(f"\n--- Cluster Purity Analysis ---")
    print(f"Average Cluster Purity: {avg_purity:.2f}%")
    if purities:
        print(f"Minimum Cluster Purity: {min(purities):.2f}%")
        print(f"Maximum Cluster Purity: {max(purities):.2f}%")
    
    print(f"\nAll results saved to {output_dir}")
# Out:
# === community_results\fast_greedy_communities. CLUSTERING PERFORMANCE METRICS ===
#
# --- Raw Cluster Evaluation ---
# Adjusted Rand Index: -0.0020
# Normalized Mutual Information: 0.1382
# Homogeneity: 0.1565
# Completeness: 0.1237
# V-measure: 0.1382
#
# --- Cluster-to-Floor Mapped Evaluation ---
# Accuracy: 0.4448
# Precision: 0.7277
# Recall: 0.4448
# F1-Score: 0.3555
# Adjusted Rand Index: 0.0542
# Normalized Mutual Information: 0.1651
# --- Cluster Purity Analysis ---
# Average Cluster Purity: 94.19%
# Minimum Cluster Purity: 16.67%
# Maximum Cluster Purity: 100.00%
#
# All results saved to ./results/community_results\fast_greedy_communities./
#
# === community_results\gat_gnn_communities. CLUSTERING PERFORMANCE METRICS ===
#
# --- Raw Cluster Evaluation ---
# Adjusted Rand Index: 0.1153
# Normalized Mutual Information: 0.3035
# Homogeneity: 0.3026
# Completeness: 0.3045
# V-measure: 0.3035
#
# --- Cluster-to-Floor Mapped Evaluation ---
# Accuracy: 0.4952
# Precision: 0.5066
# Recall: 0.4952
# F1-Score: 0.4052
# Adjusted Rand Index: 0.1533
# Normalized Mutual Information: 0.2817
# --- Cluster Purity Analysis ---
# Average Cluster Purity: 58.03%
# Minimum Cluster Purity: 25.00%
# Maximum Cluster Purity: 100.00%
#
# All results saved to ./results/community_results\gat_gnn_communities./
#
# === community_results\gcn_gnn_communities. CLUSTERING PERFORMANCE METRICS ===
#
# --- Raw Cluster Evaluation ---
# Adjusted Rand Index: 0.0282
# Normalized Mutual Information: 0.1280
# Homogeneity: 0.1503
# Completeness: 0.1114
# V-measure: 0.1280
#
# --- Cluster-to-Floor Mapped Evaluation ---
# Accuracy: 0.3900
# Precision: 0.2629
# Recall: 0.3900
# F1-Score: 0.2887
# Adjusted Rand Index: 0.0872
# Normalized Mutual Information: 0.1032
# --- Cluster Purity Analysis ---
# Average Cluster Purity: 45.38%
# Minimum Cluster Purity: 21.92%
# Maximum Cluster Purity: 100.00%
#
# All results saved to ./results/community_results\gcn_gnn_communities./
#
# === community_results\infomap_communities. CLUSTERING PERFORMANCE METRICS ===
#
# --- Raw Cluster Evaluation ---
# Adjusted Rand Index: -0.0009
# Normalized Mutual Information: 0.1700
# Homogeneity: 0.2614
# Completeness: 0.1260
# V-measure: 0.1700
#
# --- Cluster-to-Floor Mapped Evaluation ---
# Accuracy: 0.4597
# Precision: 0.5775
# Recall: 0.4597
# F1-Score: 0.4007
# Adjusted Rand Index: 0.0926
# Normalized Mutual Information: 0.1593
# --- Cluster Purity Analysis ---
# Average Cluster Purity: 82.52%
# Minimum Cluster Purity: 16.67%
# Maximum Cluster Purity: 100.00%
#
# All results saved to ./results/community_results\infomap_communities./
#
# === community_results\label_propagation_communities. CLUSTERING PERFORMANCE METRICS ===
#
# --- Raw Cluster Evaluation ---
# Adjusted Rand Index: -0.0043
# Normalized Mutual Information: 0.1587
# Homogeneity: 0.2233
# Completeness: 0.1231
# V-measure: 0.1587
#
# --- Cluster-to-Floor Mapped Evaluation ---
# Accuracy: 0.4533
# Precision: 0.6301
# Recall: 0.4533
# F1-Score: 0.3791
# Adjusted Rand Index: 0.0691
# Normalized Mutual Information: 0.1627
# --- Cluster Purity Analysis ---
# Average Cluster Purity: 86.78%
# Minimum Cluster Purity: 16.67%
# Maximum Cluster Purity: 100.00%
#
# All results saved to ./results/community_results\label_propagation_communities./
#
# === community_results\leiden_communities. CLUSTERING PERFORMANCE METRICS ===
#
# --- Raw Cluster Evaluation ---
# Adjusted Rand Index: -0.0006
# Normalized Mutual Information: 0.1310
# Homogeneity: 0.1703
# Completeness: 0.1065
# V-measure: 0.1310
#
# --- Cluster-to-Floor Mapped Evaluation ---
# Accuracy: 0.4437
# Precision: 0.6718
# Recall: 0.4437
# F1-Score: 0.3651
# Adjusted Rand Index: 0.0660
# Normalized Mutual Information: 0.1552
# --- Cluster Purity Analysis ---
# Average Cluster Purity: 92.36%
# Minimum Cluster Purity: 21.43%
# Maximum Cluster Purity: 100.00%
#
# All results saved to ./results/community_results\leiden_communities./
#
# === community_results\louvain_communities. CLUSTERING PERFORMANCE METRICS ===
#
# --- Raw Cluster Evaluation ---
# Adjusted Rand Index: -0.0018
# Normalized Mutual Information: 0.1303
# Homogeneity: 0.1692
# Completeness: 0.1060
# V-measure: 0.1303
#
# --- Cluster-to-Floor Mapped Evaluation ---
# Accuracy: 0.4437
# Precision: 0.6722
# Recall: 0.4437
# F1-Score: 0.3651
# Adjusted Rand Index: 0.0654
# Normalized Mutual Information: 0.1557
# --- Cluster Purity Analysis ---
# Average Cluster Purity: 92.39%
# Minimum Cluster Purity: 21.43%
# Maximum Cluster Purity: 100.00%
#
# All results saved to ./results/community_results\louvain_communities./
#
# === community_results\Node2Vec_communities. CLUSTERING PERFORMANCE METRICS ===
#
# --- Raw Cluster Evaluation ---
# Adjusted Rand Index: 0.4433
# Normalized Mutual Information: 0.5722
# Homogeneity: 0.6009
# Completeness: 0.5462
# V-measure: 0.5722
#
# --- Cluster-to-Floor Mapped Evaluation ---
# Accuracy: 0.6918
# Precision: 0.6335
# Recall: 0.6918
# F1-Score: 0.6572
# Adjusted Rand Index: 0.5813
# Normalized Mutual Information: 0.6003
# --- Cluster Purity Analysis ---
# Average Cluster Purity: 75.77%
# Minimum Cluster Purity: 22.54%
# Maximum Cluster Purity: 100.00%
#
# All results saved to ./results/community_results\Node2Vec_communities./

# %%
import os
import json
import pandas as pd

def compile_metrics_to_table(root_dir):
    """
    Belirtilen dizin ve alt dizinlerindeki tüm performance_metrics.json
    dosyalarını okur ve bir Pandas DataFrame (tablo) haline getirir.
    """
    all_data = []

    # os.walk ile tüm alt klasörleri geziyoruz
    for root, dirs, files in os.walk(root_dir):
        if 'performance_metrics.json' in files:
            file_path = os.path.join(root, 'performance_metrics.json')
            
            # Klasör adını al (Örn: Node2Vec_communities)
            folder_name = os.path.basename(root)
            
            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    metrics = json.load(f)
                    
                    # Klasör ismini veriye 'Algorithm' sütunu olarak ekle
                    metrics['Algorithm'] = folder_name
                    
                    all_data.append(metrics)
            except Exception as e:
                print(f"Hata: {file_path} dosyası okunamadı. Sebebi: {e}")

    # Listeyi DataFrame'e (Tabloya) çevir
    if all_data:
        df = pd.DataFrame(all_data)
        
        # 'Algorithm' sütununu en başa al
        cols = ['Algorithm'] + [c for c in df.columns if c != 'Algorithm']
        df = df[cols]
        
        # Algoritma ismine göre sırala (isteğe bağlı)
        df = df.sort_values(by='Algorithm').reset_index(drop=True)
        
        return df
    else:
        print("Hiçbir performance_metrics.json dosyası bulunamadı.")
        return None

# --- KULLANIM ---

# Buraya taramak istediğin ANA klasörün yolunu yazmalısın.
# Windows yolu olduğu için string'in başına 'r' koyuyoruz.
search_path = r"./results/community_results" 

# Fonksiyonu çalıştır
df_results = compile_metrics_to_table(search_path)

if df_results is not None:
    # Tabloyu ekrana yazdır
    print("Tüm Sonuçlar Tablosu:")
    print(df_results)

    # İstersen sonuçları Excel veya CSV olarak kaydedebilirsin:
    # df_results.to_csv("tum_sonuclar.csv", index=False)
    df_results.to_excel("tum_sonuclar2.xlsx", index=False)
# Out:
# Tüm Sonuçlar Tablosu:
#                        Algorithm   raw_ari   raw_nmi  raw_homogeneity  \
# 0           Node2Vec_communities  0.443271  0.572218         0.600857
# 1        fast_greedy_communities -0.001974  0.138191         0.156520
# 2            gat_gnn_communities  0.115348  0.303545         0.302598
# 3            gcn_gnn_communities  0.028238  0.127976         0.150296
# 4            infomap_communities -0.000900  0.170046         0.261381
# 5  label_propagation_communities -0.004267  0.158697         0.223265
# 6             leiden_communities -0.000631  0.131013         0.170299
# 7            louvain_communities -0.001812  0.130332         0.169195
#
#    raw_completeness  raw_v_measure  mapped_ari  mapped_nmi  \
# 0          0.546185       0.572218    0.581278    0.600319
# 1          0.123704       0.138191    0.054220    0.165127
# 2          0.304499       0.303545    0.153272    0.281730
# 3          0.111428       0.127976    0.087177    0.103190
# 4          0.126013       0.170046    0.092554    0.159342
# 5          0.123097       0.158697    0.069073    0.162736
# 6          0.106456       0.131013    0.066015    0.155155
# 7          0.105988       0.130332    0.065436    0.155669
#
#    mapped_homogeneity  mapped_completeness  mapped_v_measure  mapped_accuracy  \
# 0            0.569497             0.634668          0.600319         0.691817
# 1            0.105095             0.385098          0.165127         0.444798
# 2            0.212280             0.418719          0.281730         0.495218
# 3            0.075286             0.163962          0.103190         0.390011
# 4            0.118910             0.241434          0.159342         0.459660
# 5            0.111836             0.298674          0.162736         0.453291
# 6            0.105418             0.293746          0.155155         0.443737
# 7            0.105661             0.295549          0.155669         0.443737
#
#    mapped_precision  mapped_recall  mapped_f1
# 0          0.633458       0.691817   0.657196
# 1          0.727689       0.444798   0.355456
# 2          0.506576       0.495218   0.405230
# 3          0.262859       0.390011   0.288721
# 4          0.577513       0.459660   0.400672
# 5          0.630110       0.453291   0.379138
# 6          0.671790       0.443737   0.365117
# 7          0.672175       0.443737   0.365116

# %% [markdown]
# ##
